# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/iphone_results (1).csv")

# %%
df.head(10)
# Out:
#                                      Description  \
# 0               Apple iPhone 11 (128GB) - Yellow
# 1                Apple iPhone XR (128GB) - Coral
# 2                 Apple iPhone 13 (128GB) - Blue
# 3             Apple iPhone 13 (128GB) - Midnight
# 4            Apple iPhone 13 (128GB) - Starlight
# 5               Apple iPhone 13 (256 GB) - Green
# 6               Apple iPhone 12 (128GB) - Purple
# 7  Apple iPhone 13 Pro Max (256GB) - Sierra Blue
# 8      Apple iPhone 13 Pro (128GB) - Sierra Blue
# 9        Apple iPhone 13 (128GB) - (Product) RED
#
#   RAM(Random Processing memory)     Price  Rating ReviewCount
# 0                        128 GB    49,900     4.5         259
# 1                        128 GB    42,999     4.5       7,599
# 2                        128 GB    68,900     4.6       6,824
# 3                        128 GB    69,900     4.6       6,824
# 4                        128 GB    69,900     4.6       6,824
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Description                    357 non-null    object
#  1   RAM(Random Processing memory)  357 non-null    object
#  2   Price                          357 non-null    object
#  3   Rating                         357 non-null    float64
#  4   ReviewCount                    357 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 14.1+ KB

# %%
df.shape
# Out:
# (357, 5)

# %%
df.isnull()
# Out:
#      Description  RAM(Random Processing memory)  Price  Rating  ReviewCount
# 0          False                          False  False   False        False
# 1          False                          False  False   False        False
# 2          False                          False  False   False        False
# 3          False                          False  False   False        False
# 4          False                          False  False   False        False
# ..           ...                            ...    ...     ...          ...
# 352        False                          False  False   False        False
# 353        False                          False  False   False        False
# 354        False                          False  False   False        False
# 355        False                          False  False   False        False
# 356        False                          False  False   False        False
#
# [357 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Description                      0
# RAM(Random Processing memory)    0
# Price                            0
# Rating                           0
# ReviewCount                      0
# dtype: int64
