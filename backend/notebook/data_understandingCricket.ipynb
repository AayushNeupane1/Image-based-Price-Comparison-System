# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/Cricket.csv")

# %%
df.shape
# Out:
# (1224, 9)

# %%
df.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'image', 'link', 'ratings',
#        'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name              object
# main_category     object
# sub_category      object
# image             object
# link              object
# ratings           object
# no_of_ratings     object
# discount_price    object
# actual_price      object
# dtype: object

# %%
df.size
# Out:
# 11016

# %%
df.ndim
# Out:
# 2

# %%
df.head()
# Out:
#                                                 name     main_category  \
# 0  Tusker Cricket Bat Toe Protector, Self Adhesiv...  sports & fitness
# 1  Amazon Brand - Symactive Heavy Tennis Cricket ...  sports & fitness
# 2  Lycan Safety Anti Crack Water Proof Cricket Ba...  sports & fitness
# 3  A2Z HUB Wooden Cricket Stumps Set of 6 with 4 ...  sports & fitness
# 4  Xtroke Popular Willow Scoop Cricket Bat for Al...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cricket  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cricket  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2      Cricket  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3      Cricket  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4      Cricket  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
print("Missing values of data:")
df.isnull().sum()
# Out:
# Missing values of data:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings           258
# no_of_ratings     258
# discount_price    160
# actual_price       34
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1224 non-null   object
#  1   main_category   1224 non-null   object
#  2   sub_category    1224 non-null   object
#  3   image           1224 non-null   object
#  4   link            1224 non-null   object
#  5   ratings         966 non-null    object
#  6   no_of_ratings   966 non-null    object
#  7   discount_price  1064 non-null   object
#  8   actual_price    1190 non-null   object
# dtypes: object(9)
# memory usage: 86.2+ KB
